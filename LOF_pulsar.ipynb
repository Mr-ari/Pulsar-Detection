# %%
from pyod.models.lof import LOF
from sklearn.neighbors import LocalOutlierFactor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pulsar = pd.read_csv('Documents/Pulsar-Detection/HTRU2/HTRU_2.csv')

# %%
pulsar.head()
# Out:
#    Mean_of_the_integrated_profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard_deviation_of_the_integrated_profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess_kurtosis_of_the_integrated_profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
df = pulsar.copy()
df = df.drop(df.columns[[8]], axis=1)
df.head()
# Out:
#    Mean_of_the_integrated_profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard_deviation_of_the_integrated_profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess_kurtosis_of_the_integrated_profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
clf = LocalOutlierFactor(n_neighbors=5,contamination=0.1)

# %%
clf.fit(df)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.1, leaf_size=30,
#                    metric='minkowski', metric_params=None, n_jobs=None,
#                    n_neighbors=5, novelty=False, p=2)

# %%
print(clf.negative_outlier_factor_)
plt.hist(clf.negative_outlier_factor_)
# Out:
# [-1.05966756 -1.23629594 -0.98086172 ... -1.11859661 -1.05996862
#  -1.28872469]
# (array([1.0000e+00, 1.0000e+00, 5.0000e+00, 3.0000e+00, 4.0000e+00,
#         1.2000e+01, 2.1000e+01, 1.1000e+02, 1.0060e+03, 1.6735e+04]),
#  array([-4.27832452, -3.93934325, -3.60036198, -3.26138071, -2.92239944,
#         -2.58341817, -2.2444369 , -1.90545563, -1.56647436, -1.22749308,
#         -0.88851181]),
#  <a list of 10 Patch objects>)

# %%
pulsar.ix[0,0]
# Out:
# /home/ari/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 140.5625

# %%
pulsar.head()
# Out:
#    Mean_of_the_integrated_profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard_deviation_of_the_integrated_profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess_kurtosis_of_the_integrated_profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
sorted_val = pulsar.sort_values(by = 'scores' , ascending = True)

# %%
sorted_val.head()
# Out:
#       Mean_of_the_integrated_profile  \
# 9111                       84.664062
# 758                        59.351562
# 938                       171.835938
# 1677                      111.218750
# 2953                       66.796875
#
#       Standard_deviation_of_the_integrated_profile  \
# 9111                                     82.484021
# 758                                      76.784458
# 938                                      43.733886
# 1677                                     71.325173
# 2953                                     67.402865
#
#       Excess_kurtosis_of_the_integrated_profile  \
# 9111                                   0.934228
# 758                                    1.536309
# 938                                   -0.788434
# 1677                                   0.333783
# 2953                                   1.134214
#
#       Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# ...

# %%
temp = sorted_val[:1639]
temp.head()
# Out:
#       Mean_of_the_integrated_profile  \
# 9111                       84.664062
# 758                        59.351562
# 938                       171.835938
# 1677                      111.218750
# 2953                       66.796875
#
#       Standard_deviation_of_the_integrated_profile  \
# 9111                                     82.484021
# 758                                      76.784458
# 938                                      43.733886
# 1677                                     71.325173
# 2953                                     67.402865
#
#       Excess_kurtosis_of_the_integrated_profile  \
# 9111                                   0.934228
# 758                                    1.536309
# 938                                   -0.788434
# 1677                                   0.333783
# 2953                                   1.134214
#
#       Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# ...

# %%
temp[temp['class_labels'] == 1]
# Out:
#        Mean_of_the_integrated_profile  \
# 14412                       39.843750
# 10691                       36.039062
# 11292                       37.484375
# 9288                        57.554688
# 14467                       96.070312
# 5006                       117.398438
# 4834                        60.523438
# 5156                        99.937500
# 11220                       70.289062
# 8321                        47.203125
# 7217                        65.125000
# 9283                        78.421875
# 1536                        76.054688
# 11163                       16.453125
# 3477                        32.515625
# 7617                        78.101562
# 7258                        68.468750
# 6260                        76.671875
# 3764                        35.179688
# 7132                        78.953125
# 3582                        51.101562
# 11349                       25.679688
# 11310                        8.250000
# ...

# %%
217/1639
# Out:
# 0.13239780353874314
