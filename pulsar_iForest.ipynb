# %%
from pyod.models.iforest import IForest
import pandas as pd
import numpy as np

# %%
pulsar = pd.read_csv('Documents/Pulsar-Detection/HTRU2/HTRU_2.csv')

# %%
pulsar.head()
# Out:
#    Mean_of_the_integrated_profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard_deviation_of_the_integrated_profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess_kurtosis_of_the_integrated_profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
pulsar = pulsar.drop('class_labels' , 1)

# %%
pulsar.head()
# Out:
#    Mean_of_the_integrated_profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard_deviation_of_the_integrated_profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess_kurtosis_of_the_integrated_profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
type(pulsar)
# Out:
# pandas.core.frame.DataFrame

# %%
clf = IForest()

# %%
clf.fit(pulsar)
# Out:
# /home/ari/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# IForest(behaviour='old', bootstrap=False, contamination=0.1, max_features=1.0,
#     max_samples='auto', n_estimators=100, n_jobs=1, random_state=None,
#     verbose=0)

# %%
print(sorted(clf.decision_scores_))
# Out:
# [-0.15781709455182186, -0.1574761533086526, -0.15732648373533797, -0.15730734869293383, -0.1571954034144023, -0.15717639934146926, -0.1571336874578314, -0.15706116117860242, -0.15689652849632651, -0.15688799376130214, -0.15685307063872928, -0.15667059731961008, -0.156621137667873, -0.15659302819787446, -0.15654340365212993, -0.15644015100106984, -0.1564345334105287, -0.1563624196195081, -0.1563384420346276, -0.1563051697863238, -0.15628842455651992, -0.15625720057519693, -0.15623657018898762, -0.1562001459866556, -0.1561981638821191, -0.15616157733286468, -0.15615260581874713, -0.15614982041798853, -0.1561390847283396, -0.15612888567926092, -0.15606414329385349, -0.15605468975730286, -0.15604580191845974, -0.15604282293022076, -0.15603928039622345, -0.15599840943840076, -0.15597240676515822, -0.1559379411479377, -0.15590159878638837, -0.15589439477247685, -0.15585944598611318, -0.15584210806585647, -0.15583410497620337, -0.15583084401978115, -0.15579070568918513, -0.15572710264659168
# ...

# %%
pulsar['scores'] = clf.decision_scores_

# %%
pulsar.head()
# Out:
#    Mean_of_the_integrated_profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard_deviation_of_the_integrated_profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess_kurtosis_of_the_integrated_profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
df = pd.read_csv('Documents/Pulsar-Detection/HTRU2/HTRU_2.csv')

# %%
df['scores'] = clf.decision_scores_

# %%
df.head()
# Out:
#    Mean_of_the_integrated_profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard_deviation_of_the_integrated_profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess_kurtosis_of_the_integrated_profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
df.tail()
# Out:
#        Mean_of_the_integrated_profile  \
# 17893                      136.429688
# 17894                      122.554688
# 17895                      119.335938
# 17896                      114.507812
# 17897                       57.062500
#
#        Standard_deviation_of_the_integrated_profile  \
# 17893                                     59.847421
# 17894                                     49.485605
# 17895                                     59.935939
# 17896                                     53.902400
# 17897                                     85.797340
#
#        Excess_kurtosis_of_the_integrated_profile  \
# 17893                                  -0.187846
# 17894                                   0.127978
# 17895                                   0.159363
# 17896                                   0.201161
# 17897                                   1.406391
#
#        Skewness_of_the_integrated_profile  Mean_of_the_DM-SNR_curve  \
# ...

# %%
df[df['class_labels'] == 0]
# Out:
#        Mean_of_the_integrated_profile  \
# 0                          140.562500
# 1                          102.507812
# 2                          103.015625
# 3                          136.750000
# 4                           88.726562
# 5                           93.570312
# 6                          119.484375
# 7                          130.382812
# 8                          107.250000
# 9                          107.257812
# 10                         142.078125
# 11                         133.257812
# 12                         134.960938
# 13                         117.945312
# 14                         138.179688
# 15                         114.367188
# 16                         109.640625
# 17                         100.851562
# 18                         136.093750
# 20                         100.890625
# 21                         105.445312
# 22                          95.867188
# 23                         117.367188
# ...
